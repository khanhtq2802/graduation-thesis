# %%
from datasets import load_dataset, DatasetDict, Dataset, concatenate_datasets
import random
import string

from transformers import AutoModelForSequenceClassification, AutoTokenizer, AutoConfig, DataCollatorWithPadding, AdamW, get_scheduler, MarianMTModel, MarianTokenizer
import torch
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
from IPython.display import clear_output
from torch.nn.utils.rnn import pad_sequence
import gc

# %%
# # load tu file hue va seoud-label
# hue_dataset = load_dataset("csv", data_files="../data/hue-label.csv")
# hue_dataset['train'] = hue_dataset["train"].filter(lambda x: x["labels"] is not None)
# seoul_dataset = load_dataset("csv", data_files="../data/seoul-label.csv")
# seoul_dataset['train'] = seoul_dataset["train"].filter(lambda x: x["labels"] is not None)
# # drop cot
# hue_dataset = hue_dataset.remove_columns(["positive_score", "negative_score", "neutral_score", "vn_text"])
# seoul_dataset = seoul_dataset.remove_columns(["vn_text", "confidence"])
# # gop 2 datasets vao datasets
# raw_dataset = DatasetDict({'train': concatenate_datasets([hue_dataset['train'], seoul_dataset['train']])})
# # loai bo "en: " o cot ex_text
# def remove_en(example):
#     return {"en_text": example["en_text"].replace("en: ", "")}
# raw_dataset = raw_dataset.map(remove_en)
# # them aspect all vao cot labels
# def add_all(example):
#     return {"labels": 'all-' + example["labels"]}
# raw_dataset = raw_dataset.map(add_all)
# # chia ra train va test
# raw_dataset = raw_dataset['train'].train_test_split(test_size=0.2, shuffle=True)
# # luu files
# raw_dataset["train"].to_csv('../data/raw_dataset/train.csv')
# raw_dataset["test"].to_csv('../data/raw_dataset/test.csv')

# %% [markdown]
# load and process data

# %%
data_files = {
    "train": "../data/raw_dataset/train.csv",
    "test": "../data/raw_dataset/test.csv"
}
raw_dataset = load_dataset("csv", data_files=data_files)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# Tang cuong va can bang du lieu

# %%
# Sử dụng thiết bị (GPU nếu có sẵn, nếu không thì sử dụng CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Danh sách các ngôn ngữ
languages = ['de', 'es', 'ru', 'fr']
translate_models = {}
translate_tokenizers = {}
# Tải mô hình và tokenizer, sau đó chuyển mô hình sang thiết bị
for language in languages:
    translate_models['to' + language] = MarianMTModel.from_pretrained("Helsinki-NLP/opus-mt-en-" + language).to(device)
    translate_tokenizers['to' + language] = MarianTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-" + language)
    translate_models['from' + language] = MarianMTModel.from_pretrained("Helsinki-NLP/opus-mt-" + language + "-en").to(device)
    translate_tokenizers['from' + language] = MarianTokenizer.from_pretrained("Helsinki-NLP/opus-mt-" + language + "-en")
languages.append('en')

# %%
# Hàm back-translate
def back_translate(texts):
    language = random.choice(languages)
    if language == 'en':
        return texts
    # Dịch từ English sang ngôn ngữ đích
    model = translate_models['to' + language]
    tokenizer = translate_tokenizers['to' + language]
    with torch.no_grad():
        inputs = tokenizer(texts, return_tensors="pt", padding=True).to(device)
        translated = model.generate(**inputs)
    texts = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]
    # Giải phóng bộ nhớ GPU cho model và inputs
    del inputs
    del translated
    torch.cuda.empty_cache()
    # Dịch từ ngôn ngữ đích quay lại English
    model = translate_models['from' + language]
    tokenizer = translate_tokenizers['from' + language]
    with torch.no_grad():
        inputs = tokenizer(texts, return_tensors="pt", padding=True).to(device)
        translated = model.generate(**inputs)
    texts = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]
    # Giải phóng bộ nhớ GPU cho model và inputs
    del inputs
    del translated
    torch.cuda.empty_cache()
    del model
    del tokenizer
    del language
    gc.collect()
    return texts
# loai bo aspect cua cau sau
def remove_aspect(text):
    text = text.replace("all: ", "")
    text = text.replace("amenities: ", "")
    text = text.replace("cultural heritage: ", "")
    text = text.replace("people: ", "")
    text = text.replace("management: ", "")
    text = text.replace("nature: ", "")
    return text
# loai bo dau cau cua cau truoc
def remove_last_punctuation(text):
    while text[-1] in string.punctuation:
        text = text[:-1]
    return text

def create_train_dataset(raw_datasets, batch_size=48, use_back_translate=True):
    datasets = DatasetDict({'train': raw_datasets['train'].shuffle()})
    if use_back_translate:
        en_text = datasets['train']['en_text']
        new_en_text = []
        for i in range(0, len(en_text), batch_size):
            new_en_text.extend(back_translate(en_text[i : i + batch_size]))
        datasets['train'] = datasets['train'].remove_columns('en_text').add_column('en_text', new_en_text)
    #################################################################################################
    for name in datasets:
        data_dict = {"en_text": [], "labels": [], "type": []}
        for item in datasets[name]:
            text = item['en_text']
            aspect2label = {'all': 0, 'amn': 0, 'ch': 0, 'ppl': 0, 'mgt': 0, 'nat': 0,}
            labels = item['labels'].split()
            for label in labels:
                try:
                    key, value = label.split('-')
                except:
                    print("Unknown label with text:" + text)
                if(key not in aspect2label or value not in ['0', '1', '2', '3']):
                    raise Exception("Unknown label:", label)
                aspect2label[key] = int(value)
            data_dict["en_text"].append("all: " + text);        data_dict["labels"].append(aspect2label['all']);  data_dict["type"].append('all-' + str(aspect2label['all']))
            data_dict["en_text"].append("amenities: " + text);         data_dict["labels"].append(aspect2label['amn']);  data_dict["type"].append('amn-' + str(aspect2label['amn']))
            data_dict["en_text"].append("cultural heritage: " + text); data_dict["labels"].append(aspect2label['ch']);   data_dict["type"].append('ch-' + str(aspect2label['ch']))
            data_dict["en_text"].append("people: " + text);            data_dict["labels"].append(aspect2label['ppl']);  data_dict["type"].append('ppl-' + str(aspect2label['ppl']))
            data_dict["en_text"].append("management: " + text);        data_dict["labels"].append(aspect2label['mgt']);  data_dict["type"].append('mgt-' + str(aspect2label['mgt']))
            data_dict["en_text"].append("nature: " + text);            data_dict["labels"].append(aspect2label['nat']);  data_dict["type"].append('nat-' + str(aspect2label['nat']))
        datasets[name] = Dataset.from_dict(DatasetDict(data_dict))
    #################################################################################################
    type_counts = {}
    for type_ in datasets['train']['type']:
        if type_ in type_counts:
            type_counts[type_] += 1
        else:
            type_counts[type_] = 1
    max_count = max(type_counts.values())
    add_datasets = {"en_text": [], "labels": [], "type": []}
    #-------------------------------------------------------------------------------------------------
    type_3 = ["all-3", "amn-3", "ch-3", "ppl-3", "mgt-3", "nat-3"]
    for type in type_3:
        tmp_1_datasets = datasets['train'].filter(lambda x: x["type"] == type.replace('3', '1'))
        tmp_2_datasets = datasets['train'].filter(lambda x: x["type"] == type.replace('3', '2'))
        tmp_3_datasets = datasets['train'].filter(lambda x: x["type"] == type)
        num_rows_1 = tmp_1_datasets.num_rows
        num_rows_2 = tmp_2_datasets.num_rows
        num_rows_3 = tmp_3_datasets.num_rows
        for i in range(num_rows_3, max_count, 2):
            # 3 + any
            first_sentence = tmp_3_datasets[random.randint(0, num_rows_3 - 1)]["en_text"]
            second_sentence = datasets['train'][random.randint(0, datasets['train'].num_rows - 1)]["en_text"]
            if random.randint(0, 1):
                add_datasets['en_text'].append(remove_last_punctuation(first_sentence) + ", " + remove_aspect(second_sentence))
                add_datasets['labels'].append(3)
                add_datasets['type'].append(type)
            else:
                add_datasets['en_text'].append(remove_last_punctuation(second_sentence) + ", " + remove_aspect(first_sentence))
                add_datasets['labels'].append(3)
                add_datasets['type'].append(type)
            # 1 + 2
            first_sentence = tmp_1_datasets[random.randint(0, num_rows_1 - 1)]["en_text"]
            second_sentence = tmp_2_datasets[random.randint(0, num_rows_2 - 1)]["en_text"]
            if random.randint(0, 1):
                add_datasets['en_text'].append(remove_last_punctuation(first_sentence) + ", " + remove_aspect(second_sentence))
                add_datasets['labels'].append(3)
                add_datasets['type'].append(type)
            else:
                add_datasets['en_text'].append(remove_last_punctuation(second_sentence) + ", " + remove_aspect(first_sentence))
                add_datasets['labels'].append(3)
                add_datasets['type'].append(type)
    #-------------------------------------------------------------------------------------------------
    type_0 = ["all-0", "amn-0", "ch-0", "ppl-0", "mgt-0", "nat-0"]
    for type in type_0:
        tmp_datasets = datasets['train'].filter(lambda x: x["type"] == type)
        num_rows = tmp_datasets.num_rows
        for i in range(num_rows, max_count):
            # 0 + 0
            first_sentence = tmp_datasets[random.randint(0, num_rows - 1)]["en_text"]
            second_sentence = tmp_datasets[random.randint(0, num_rows - 1)]["en_text"]
            add_datasets['en_text'].append(remove_last_punctuation(first_sentence) + ", " + remove_aspect(second_sentence))
            add_datasets['labels'].append(0)
            add_datasets['type'].append(type)
    #-------------------------------------------------------------------------------------------------
    type_1 = ["all-1", "amn-1", "ch-1", "ppl-1", "mgt-1", "nat-1"]
    for type in type_1:
        tmp_0_datasets = datasets['train'].filter(lambda x: x["type"] == type.replace('1', '0'))
        tmp_1_datasets = datasets['train'].filter(lambda x: x["type"] == type)
        num_rows_0 = tmp_0_datasets.num_rows
        num_rows_1 = tmp_1_datasets.num_rows
        for i in range(num_rows_1, max_count, 2):
            # 0 + 1
            first_sentence = tmp_0_datasets[random.randint(0, num_rows_0 - 1)]["en_text"]
            second_sentence = tmp_1_datasets[random.randint(0, num_rows_1 - 1)]["en_text"]
            if random.randint(0, 1):
                add_datasets['en_text'].append(remove_last_punctuation(first_sentence) + ", " + remove_aspect(second_sentence))
                add_datasets['labels'].append(1)
                add_datasets['type'].append(type)
            else:
                add_datasets['en_text'].append(remove_last_punctuation(second_sentence) + ", " + remove_aspect(first_sentence))
                add_datasets['labels'].append(1)
                add_datasets['type'].append(type)
            # 1 + 1
            first_sentence = tmp_1_datasets[random.randint(0, num_rows_1 - 1)]["en_text"]
            second_sentence = tmp_1_datasets[random.randint(0, num_rows_1 - 1)]["en_text"]
            add_datasets['en_text'].append(remove_last_punctuation(first_sentence) + ", " + remove_aspect(second_sentence))
            add_datasets['labels'].append(1)
            add_datasets['type'].append(type)
    #-------------------------------------------------------------------------------------------------
    type_2 = ["all-2", "amn-2", "ch-2", "ppl-2", "mgt-2", "nat-2"]
    for type in type_2:
        tmp_0_datasets = datasets['train'].filter(lambda x: x["type"] == type.replace('2', '0'))
        tmp_2_datasets = datasets['train'].filter(lambda x: x["type"] == type)
        num_rows_0 = tmp_0_datasets.num_rows
        num_rows_2 = tmp_2_datasets.num_rows
        for i in range(num_rows_2, max_count, 2):
            # 0 + 2
            first_sentence = tmp_0_datasets[random.randint(0, num_rows_0 - 1)]["en_text"]
            second_sentence = tmp_2_datasets[random.randint(0, num_rows_2 - 1)]["en_text"]
            if random.randint(0, 1):
                add_datasets['en_text'].append(remove_last_punctuation(first_sentence) + ", " + remove_aspect(second_sentence))
                add_datasets['labels'].append(2)
                add_datasets['type'].append(type)
            else:
                add_datasets['en_text'].append(remove_last_punctuation(second_sentence) + ", " + remove_aspect(first_sentence))
                add_datasets['labels'].append(2)
                add_datasets['type'].append(type)
            # 2 + 2
            first_sentence = tmp_2_datasets[random.randint(0, num_rows_2 - 1)]["en_text"]
            second_sentence = tmp_2_datasets[random.randint(0, num_rows_2 - 1)]["en_text"]
            add_datasets['en_text'].append(remove_last_punctuation(first_sentence) + ", " + remove_aspect(second_sentence))
            add_datasets['labels'].append(2)
            add_datasets['type'].append(type)
    clear_output()
    return DatasetDict({"train": concatenate_datasets([datasets["train"], Dataset.from_dict(DatasetDict(add_datasets))])})

def create_test_dataset(raw_datasets):
    datasets = DatasetDict({
        'train': raw_datasets['train'],
        'test': raw_datasets['test']})
    for name in datasets:
        data_dict = {"en_text": [], "labels": [], "type": []}
        for item in datasets[name]:
            text = item['en_text']
            aspect2label = {'all': 0, 'amn': 0, 'ch': 0, 'ppl': 0, 'mgt': 0, 'nat': 0,}
            labels = item['labels'].split()
            for label in labels:
                try:
                    key, value = label.split('-')
                except:
                    print("Unknown label with text:" + text)
                if(key not in aspect2label or value not in ['0', '1', '2', '3']):
                    raise Exception("Unknown label:", label)
                aspect2label[key] = int(value)
            data_dict["en_text"].append("all: " + text);        data_dict["labels"].append(aspect2label['all']);  data_dict["type"].append('all-' + str(aspect2label['all']))
            data_dict["en_text"].append("amenities: " + text);         data_dict["labels"].append(aspect2label['amn']);  data_dict["type"].append('amn-' + str(aspect2label['amn']))
            data_dict["en_text"].append("cultural heritage: " + text); data_dict["labels"].append(aspect2label['ch']);   data_dict["type"].append('ch-' + str(aspect2label['ch']))
            data_dict["en_text"].append("people: " + text);            data_dict["labels"].append(aspect2label['ppl']);  data_dict["type"].append('ppl-' + str(aspect2label['ppl']))
            data_dict["en_text"].append("management: " + text);        data_dict["labels"].append(aspect2label['mgt']);  data_dict["type"].append('mgt-' + str(aspect2label['mgt']))
            data_dict["en_text"].append("nature: " + text);            data_dict["labels"].append(aspect2label['nat']);  data_dict["type"].append('nat-' + str(aspect2label['nat']))
        datasets[name] = Dataset.from_dict(DatasetDict(data_dict))
    return datasets

# %% [markdown]
# load model

# %%
# upload model to huggingface
# !git config --global user.email "khanh.tq2802@outlook.com"
# !git config --global user.name "khanhtq2802"
# from huggingface_hub import notebook_login
# notebook_login()
tokenizer.push_to_hub("thesis-model")
config.push_to_hub("thesis-model")
model.push_to_hub("thesis-model")
# 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
# Out:
# CommitInfo(commit_url='https://huggingface.co/khanhtq2802/thesis-model/commit/3dca0f5b1458d79e2e256f34b1f3755b2cae55b6', commit_message='Upload RobertaForSequenceClassification', commit_description='', oid='3dca0f5b1458d79e2e256f34b1f3755b2cae55b6', pr_url=None, pr_revision=None, pr_num=None)

# %%
# load model, set freeze, set device
tokenizer = AutoTokenizer.from_pretrained("khanhtq2802/thesis-model")
config = AutoConfig.from_pretrained("khanhtq2802/thesis-model")
# model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment-latest", num_labels=4, ignore_mismatched_sizes=True)
# model = AutoModelForSequenceClassification.from_pretrained("khanhtq2802/thesis-model", force_download=True)
# model = AutoModelForSequenceClassification.from_pretrained("../best_weights")
# model = AutoModelForSequenceClassification.from_pretrained("../late_weights")
model = AutoModelForSequenceClassification.from_pretrained("../mlm_backtranslate")
# Freeze all layers
for name, param in model.named_parameters():
    param.requires_grad = False
# unFreeze
for name, param in model.named_parameters():
    if name.startswith("classifier.out_proj"):
        param.requires_grad = True
for name, param in model.named_parameters():
    if name.startswith("classifier.dense"):
        param.requires_grad = True
for name, param in model.named_parameters():
    if name.startswith("roberta.encoder.layer.11"):
        param.requires_grad = True
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)
print(device)
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Trainable Parameters:", trainable_params)
# Out:
# /home/khanh/apps/miniconda3/envs/thesis/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/970 [00:00<?, ?B/s]
# cuda
# Trainable Parameters: 7681540

# %%
model

# %%
# Danh sách các aspect
aspects = ["all: ", "amenities: ", "cultural heritage: ", "people: ", "management: ", "nature: ",]
skip_tokens = 0
# Chuyển các aspect sang token và đếm số lượng token
for aspect in aspects:
    tokens = tokenizer.tokenize(aspect)
    skip_tokens = max(skip_tokens, len(tokens))
print(skip_tokens)
class CustomDataCollator:
    def __init__(self, tokenizer, mlm_probability=0.15, skip_tokens=4):
        self.tokenizer = tokenizer
        self.mlm_probability = mlm_probability
        self.skip_tokens = skip_tokens
    def __call__(self, examples):
        input_ids = [example['input_ids'] for example in examples]
        attention_mask = [example['attention_mask'] for example in examples]
        labels = [example['labels'] for example in examples]
        # Mask tokens with probability self.mlm_probability
        for i in range(len(input_ids)):
            for j in range(self.skip_tokens + 1, len(input_ids[i])):
                if random.random() < self.mlm_probability:
                    input_ids[i][j] = self.tokenizer.mask_token_id
        # Convert input_ids to tensor
        input_ids = pad_sequence([torch.tensor(sublist) for sublist in input_ids], batch_first=True, padding_value=1)
        # Pad attention_mask and convert to tensor
        attention_mask = pad_sequence([torch.tensor(sublist) for sublist in attention_mask], batch_first=True, padding_value=1)
        return {
            'labels': torch.tensor(labels),
            'input_ids': input_ids,
            'attention_mask': attention_mask,}
def tokenize_function(example):
    return tokenizer(example["en_text"], truncation=True)
data_collator_train = CustomDataCollator(
    tokenizer=tokenizer,
    mlm_probability=0.15,  # 15% masking rate
    skip_tokens=skip_tokens
)
data_collator_test = DataCollatorWithPadding(tokenizer=tokenizer)
# Out:
# 4

# %%
# load loss history from file
training_losses = []
test_losses = []
try:
    with open("losses.txt", "r") as f:
        for line in f:
            if line.strip():  # Check if line is not empty
                training_loss, test_loss = line.split(",")
                training_losses.append(float(training_loss))
                test_losses.append(float(test_loss))
except:
    print("error when load training history")

# %% [markdown]
# train

# %%
test_dataloader = DataLoader(
    create_test_dataset(raw_dataset).map(tokenize_function, batched=True).remove_columns(['en_text', 'type'])['test'], 
    shuffle=False, 
    batch_size=24, 
    collate_fn=data_collator_test)
batch_size = 12
train_dataloader = DataLoader(
    create_train_dataset(raw_dataset, use_back_translate=True).map(tokenize_function, batched=True).remove_columns(["en_text", "type"])["train"], 
    shuffle=True, 
    batch_size=batch_size, 
    collate_fn=data_collator_train)

optimizer = AdamW(model.parameters(), lr=3e-5) #before 1e-5
num_epochs = 100
num_training_steps = num_epochs * len(train_dataloader)
decay = "cosine" #constant cosine linear

lr_scheduler = get_scheduler(
    decay,
    optimizer=optimizer,
    num_warmup_steps=len(train_dataloader),
    num_training_steps=num_training_steps)
for epoch in range(num_epochs):
    # train
    model.train()
    epoch_losses = []
    for batch in train_dataloader:
        batch = {k: v.to(device) for k, v in batch.items()}

        loss = model(**batch).loss
        loss.backward()
        epoch_losses.append(loss.item())
        
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
    training_losses.append(sum(epoch_losses) / len(epoch_losses))
    # evaluation
    model.eval()  # Set the model to evaluation mode
    total_loss = 0
    with torch.no_grad():
        for batch in test_dataloader:
            total_loss += torch.nn.CrossEntropyLoss()(model(**{k: v.to(device) for k, v in batch.items() if k != 'labels'}).logits, batch['labels'].to(device)).item()
    test_losses.append(total_loss / len(test_dataloader))
    # Plotting
    clear_output(wait=True)
    plt.plot(training_losses, label="Training Loss")
    plt.plot(test_losses, label="test Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()
    # save loss history to file
    with open("losses.txt", "w") as f:
        for i in range(len(training_losses)):
            f.write(f"{training_losses[i]},{test_losses[i]}\n")
    # save model
    model.save_pretrained("../late_weights")
    if test_losses[-1] == min(test_losses):
        model.save_pretrained("../best_weights")
    # re-create train_dataloader
    if len(test_losses) >= 2:
        if test_losses[-1] >= test_losses[-2]:
            torch.cuda.empty_cache()
            train_dataloader = DataLoader(
                create_train_dataset(raw_dataset, use_back_translate=True).map(tokenize_function, batched=True).remove_columns(["en_text", "type"])["train"], 
                shuffle=True,
                batch_size=batch_size, 
                collate_fn=data_collator_train)

# %%
# model.save_pretrained("../best_weights")

# %% [markdown]
# evaluate

# %%
def evaluate_model(model, raw_datasets, device, name='train'):
    dataset = create_test_dataset(raw_datasets)

    dataloader = DataLoader(
    dataset.map(tokenize_function, batched=True).remove_columns(['en_text', 'type'])[name], 
    shuffle=False,
    batch_size=16, 
    collate_fn=data_collator_test)

    model.eval()  # Set the model to evaluation mode
    total_acc, total_loss = 0, 0
    fail_count = {
        "false-positive": 
        {"all-0": 0, "amn-0": 0, "ch-0": 0, "mgt-0": 0, "nat-0": 0, "ppl-0": 0,
        "all-1": 0, "amn-1": 0, "ch-1": 0, "mgt-1": 0, "nat-1": 0, "ppl-1": 0,
        "all-2": 0, "amn-2": 0, "ch-2": 0, "mgt-2": 0, "nat-2": 0, "ppl-2": 0,
        "all-3": 0, "amn-3": 0, "ch-3": 0, "mgt-3": 0, "nat-3": 0, "ppl-3": 0, },

        "false-negative": 
        {"all-0": 0, "amn-0": 0, "ch-0": 0, "mgt-0": 0, "nat-0": 0, "ppl-0": 0,
        "all-1": 0, "amn-1": 0, "ch-1": 0, "mgt-1": 0, "nat-1": 0, "ppl-1": 0,
        "all-2": 0, "amn-2": 0, "ch-2": 0, "mgt-2": 0, "nat-2": 0, "ppl-2": 0,
        "all-3": 0, "amn-3": 0, "ch-3": 0, "mgt-3": 0, "nat-3": 0, "ppl-3": 0, },
    }
    type_counts = {}
    for type_ in dataset[name]['type']:
        if type_ in type_counts:
            type_counts[type_] += 1
        else:
            type_counts[type_] = 1

    with torch.no_grad():
        for batch in dataloader:
            # Move data to the specified device
            inputs = {k: v.to(device) for k, v in batch.items() if k != 'labels'}
            labels = batch['labels'].to(device)

            outputs = model(**inputs)
            logits = outputs.logits  # Access the model's output logits

            # Calculate loss (optional, for reference)
            loss_fn = torch.nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)
            total_loss += loss.item()

            # Calculate accuracy
            pred_labels = torch.argmax(logits, dim=1)  # Get predicted labels
            match_labels = pred_labels == labels
            for i in range(len(match_labels)):
                if match_labels[i] == True:
                    total_acc+=1
                else:
                    text = tokenizer.decode(batch['input_ids'][i])
                    if text.startswith("<s>all: "):
                        fail_count["false-positive"]["all-" + str(pred_labels[i].item())] += 1
                        fail_count["false-negative"]["all-" + str(labels[i].item())] += 1
                    if text.startswith("<s>amenities: "):
                        fail_count["false-positive"]["amn-" + str(pred_labels[i].item())] += 1
                        fail_count["false-negative"]["amn-" + str(labels[i].item())] += 1
                    if text.startswith("<s>cultural heritage: "):
                        fail_count["false-positive"]["ch-" + str(pred_labels[i].item())] += 1
                        fail_count["false-negative"]["ch-" + str(labels[i].item())] += 1
                    if text.startswith("<s>history: "):
                        fail_count["false-positive"]["hist-" + str(pred_labels[i].item())] += 1
                        fail_count["false-negative"]["hist-" + str(labels[i].item())] += 1
                    if text.startswith("<s>people: "):
                        fail_count["false-positive"]["ppl-" + str(pred_labels[i].item())] += 1
                        fail_count["false-negative"]["ppl-" + str(labels[i].item())] += 1
                    if text.startswith("<s>management: "):
                        fail_count["false-positive"]["mgt-" + str(pred_labels[i].item())] += 1
                        fail_count["false-negative"]["mgt-" + str(labels[i].item())] += 1
                    if text.startswith("<s>nature: "):
                        fail_count["false-positive"]["nat-" + str(pred_labels[i].item())] += 1
                        fail_count["false-negative"]["nat-" + str(labels[i].item())] += 1
                    print(text)
                    print("pred: ", pred_labels[i])
                    print("labels: ", labels[i])
                    print()
    recalls = []; precisions = []; f1s = []
    # recall, precision, f1
    for key in type_counts:
        if type_counts[key] > 0:
            true_positive = type_counts[key] - fail_count["false-negative"][key]
            recall = 0; precision = 0; f1 = 0
            if true_positive != 0:
                recall = true_positive/type_counts[key]
                precision = true_positive/(true_positive + fail_count["false-positive"][key])
                f1 = 2*recall*precision/(recall + precision)
            print(key, "recall=", round(recall, 4), "precision=", round(precision, 4), "f1=", round(f1, 4))
            recalls.append(recall); precisions.append(precision); f1s.append(f1)
    # Accuracy
    print(total_acc, dataloader.dataset.num_rows)
    print("Accuracy:", round(total_acc / dataloader.dataset.num_rows, 5))
    # Loss
    print("Loss:", total_loss / len(dataloader))
    # Marco recall, precision, f1
    print("Marco-recall:", round(sum(recalls)/len(recalls), 5))
    print("Marco-precision:", round(sum(precisions)/len(precisions), 5))
    print("Marco-f1:", round(sum(f1s)/len(f1s), 5))

# %%
evaluate_model(model, raw_dataset, device, name='test')
# Out:
# Map:   0%|          | 0/17352 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Map:   0%|          | 0/4344 [00:00<?, ? examples/s]
# <s>all: We learned that the first emperor didn't like western women because they had ugly teeth (Vietnamese women dyed their teeth black, which was more to his liking.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: We learned that the first emperor didn't like western women because they had ugly teeth (Vietnamese women dyed their teeth black, which was more to his liking.</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: The English secret garden tour at 130pm was great.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: And I did not think I saw any timetable for the secret garden at the main entrance, may be it is a little secret that should not tell travellers.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>cultural heritage: 3rd palace,which I visited...small but full of surprises inside.. you must come to experience.. it is also close in everything, restaurants,banks,hotels etc</s><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: 3rd palace,which I visited...small but full of surprises inside.. you must come to experience.. it is also close in everything, restaurants,banks,hotels etc</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: But note that the Piwon is only open to guided tours that are alternatively in Korean, Japanese and English, so make sure to check the schedule and get there early because the tour of the Piwon is very popular.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>all: This citadel was bombed during the war and large parts of it are yet to be restored.</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>management: This citadel was bombed during the war and large parts of it are yet to be restored.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: Try to avoid them and you'll be fine.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: The freezing cold did not stop us from visiting the Changdeokgung Palace in Seoul Korea.</s><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>people: Totally worth it and the price as well, Good places to show also.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: Totally worth it and the price as well, Good places to show also.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>nature: Totally worth it and the price as well, Good places to show also.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: It was a shame that such big areas was not taking care of in such a amazing place, dangerous holes my little girl could fall in and weeds taking over.</s><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>cultural heritage: It was a shame that such big areas was not taking care of in such a amazing place, dangerous holes my little girl could fall in and weeds taking over.</s><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>people: It was a shame that such big areas was not taking care of in such a amazing place, dangerous holes my little girl could fall in and weeds taking over.</s><pad><pad><pad><pad><pad><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: which was a nice surprise, considering there are not many things that are free in this world.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>people: Very nice historical palace grounds, very similar to Gyeongbokgung Palace but not as grand in size and extravigance, The wooded grounds are beautiful and definetly worth a one time look for historical value and significance, an hour or so is pleanty of time for this one.</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: The tour could have been longer and detailed in my opinion.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>amenities: The tour could have been longer and detailed in my opinion.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>cultural heritage: Worst in whole of Vietnam!</s><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>amenities: the english interpretation was great and it provides an intrusion into the Korean culture beyond what we know already.</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: Free for children under 7.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>nature: the gardens are not kept well at all.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>cultural heritage: Unlike the fancy palaces in China, the palaces in Seoul are more plain but I still find them interesting.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: It's more expensive for foreigners and while I "get it" and have seen this done in other countries as well, it is a bit disappointing.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>amenities: It's more expensive for foreigners and while I "get it" and have seen this done in other countries as well, it is a bit disappointing.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>people: It is better to take a guided tour with a English guide as language is a great problem to communicate, Still i love South Korea.</s><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: Always disappointing to see racism at heratage sites but unfortunatly fairly common.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: Some road signs would have been good as we ended up walking all the way around the outside of the citadel to get to the entrance.</s><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>management: Some road signs would have been good as we ended up walking all the way around the outside of the citadel to get to the entrance.</s><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: I just wish I had more time to understand the history of each area.</s><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>cultural heritage: I just wish I had more time to understand the history of each area.</s><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: Unfortunately we had a very bad official guide.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>people: Unfortunately we had a very bad official guide.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>people: After initially being politely hassled by a cyclo driver, we decided to give in after realising how big the citadel was (this was before we'd even hit the Imperial City)!</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>nature: It is a good walk and may experience beautiful hills and ground.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: Quite disappointing considering we payd 150000 dong each for entrance.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>nature: The second elephant didn't have any obvious physical abuse, but looked demoralized and just kept swaying back and forth surrounded by its own excrement, It had no food or water either.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: Must join the secret garden tour.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: We got our whole day package through the hotel service and it was a while day with the Forbidden City in the Citadel in the morning, a pagoda with a lake view, a dragon boat trip across the lake to lunch, the imperial tombs in the afternoon and a short stop for souvenirs and crafts demonstrations before heading back to the hotel.</s>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>amenities: The staff is really unfriendly.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: On both sides of the walkway are man-made pools filled with carp (food is available for purchase).</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>management: On both sides of the walkway are man-made pools filled with carp (food is available for purchase).</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>nature: On both sides of the walkway are man-made pools filled with carp (food is available for purchase).</s><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: As they are not informative and all time wanting to end the tour.</s><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: The palace grounds are much smaller and more intimate than Gyeongbokgung Palace - and definitely not as crowded.</s><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: This palace was very beautiful and could feel about Choseon royal family's atmosphere.</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: the wars have destroyed parts of it, and there is never enough money for all the temple restorations going on.</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: the wars have destroyed parts of it, and there is never enough money for all the temple restorations going on.</s>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>people: Because we were so many, it was hard to hear the guide speak.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: This proves so much.</s><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: Avoid the cafe!</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>amenities: Avoid the cafe!</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>cultural heritage: The Palace impresses right from the start with the 'Donhwamun', it's huge two-tiered main gate.</s><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: The cafe in the garden area has lovely views but very limited choice</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>all: You can buy a 48 hour ticket if you want to spread it over longer but personally pull think that excessive.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>amenities: You can buy a 48 hour ticket if you want to spread it over longer but personally pull think that excessive.</s>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: Then there's a map showing various routes and what the buildings are.</s><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: Then there's a map showing various routes and what the buildings are.</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: I was so excited to see this given its UNESCO World Heritage Status.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>nature: MANY THANKS to the guide.. she did an excellent job of explaining in detail.. her English with an eastern-American accent was easy to understand..
# At a small hill there was a lake and stream that flowed to the lower part and a building where the Imperial family performed annual rituals to honour the planting and harvesting of crops..
# .i saw others were dressed in colourful traditional Korean clothing.. later I found out that these were tourists who had rented these.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>amenities: The secret garden is worth the 5000won as you can see a different part of the palace and there will be guide touring you around.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: There were a few other horses on the premises, but at least they were allowed to stand in the shade.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: Having successfully obtained some cash from the ATM the cyclos pressed their services on us.</s><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>people: Having successfully obtained some cash from the ATM the cyclos pressed their services on us.</s><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>cultural heritage: the tour was amazing in that old elegant city.</s><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: You can walk around the "secret places" in the palace with tourguide, There's a traditional Korean show at the end.</s><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: You can walk around the "secret places" in the palace with tourguide, There's a traditional Korean show at the end.</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>nature: You can walk around the "secret places" in the palace with tourguide, There's a traditional Korean show at the end.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: Absolutely breathtaking,and the gardens are just wonderfull,you do pay xtra to see the gardens as you only allowed to go with a guide,but the palace grounds are free wander at your leisure.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>amenities: Absolutely breathtaking,and the gardens are just wonderfull,you do pay xtra to see the gardens as you only allowed to go with a guide,but the palace grounds are free wander at your leisure.</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>management: Absolutely breathtaking,and the gardens are just wonderfull,you do pay xtra to see the gardens as you only allowed to go with a guide,but the palace grounds are free wander at your leisure.</s><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>cultural heritage: No, it was still disappointing - vast swathes of nothing interspersed with the occasional building and a lot of reconstructed ones.</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: No, it was still disappointing - vast swathes of nothing interspersed with the occasional building and a lot of reconstructed ones.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>management: Well worth a visit, I'd recommend at night, it's cooler and beautifully lit.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>amenities: A bit costly, but worth it.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: But pls, do not intimidate the guards, they are humans too.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>people: But pls, do not intimidate the guards, they are humans too.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: Worth to go there for a full day, with a lunch box and live slowly around.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: Sad to see what remains of the rich ancient architectural history that was destroyed during the war with France, then the US and now the environment.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>cultural heritage: Sad to see what remains of the rich ancient architectural history that was destroyed during the war with France, then the US and now the environment.</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>nature: it was an easily accessible and quick experience as we didn't do a tour (had already done another palace tour)
# We came for the change of the guards, which was pretty cool, with amusing music, especial the trumpet.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: I am so glad the beautiful buildings that we saw, survived.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: Very huge compound... should have a tour guide while visiting this place or else you wont understand a thingy... perhaps if you really a Korean movie fan you might have some idea what you looking at.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>nature: It is a shame that most of the buildings have been destroyed by the wars but one can still get an impression of the splendour of the ancient city.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: Can be hot with the stonework so buy one of those cheap umbrellas and take your water.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>amenities: Can be hot with the stonework so buy one of those cheap umbrellas and take your water.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: The first thing you note as you enter are the protective wall and the moat, 11 km long, running round the 520 hectare city.</s><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: The first thing you note as you enter are the protective wall and the moat, 11 km long, running round the 520 hectare city.</s><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: Still a lot to go through with the restorations, yes, but... remember that a terrible war happened here...</s><pad><pad><pad><pad><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>management: Still a lot to go through with the restorations, yes, but... remember that a terrible war happened here...</s><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>amenities: Tourist hangout but well worth it when guards make the change.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: Tourist hangout but well worth it when guards make the change.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: There are many shops to buy souvenirs but I found them overpriced and a bit tacky since it costs $120,000/person to enter The Citadel.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>amenities: There are many shops to buy souvenirs but I found them overpriced and a bit tacky since it costs $120,000/person to enter The Citadel.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>all: the palace follows the usual style of these types of buildings, There's not really much to see but the interiors of the buildings have a lot of interesting detail and if you can get a tour guide it makes the visit and understanding the context more enjoyable</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>people: the palace follows the usual style of these types of buildings, There's not really much to see but the interiors of the buildings have a lot of interesting detail and if you can get a tour guide it makes the visit and understanding the context more enjoyable</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: the palace follows the usual style of these types of buildings, There's not really much to see but the interiors of the buildings have a lot of interesting detail and if you can get a tour guide it makes the visit and understanding the context more enjoyable</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>amenities: To be honest I'm really disgusted about what happened there, and it' sur just another exemple about how they always try to cheat with the foreigner, it make me sad for vietnamese people who try do well</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: To be honest I'm really disgusted about what happened there, and it' sur just another exemple about how they always try to cheat with the foreigner, it make me sad for vietnamese people who try do well</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: To be honest I'm really disgusted about what happened there, and it' sur just another exemple about how they always try to cheat with the foreigner, it make me sad for vietnamese people who try do well</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: Similarly the Citadel site has not been restored well enough.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: The Imperial City is given a "poor" mark because of its unsophisticated management.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>management: I got confused and so disappointed, the Vietnamese women who served at the ticket table were Asian themselves, an yet they were truly horrible to me, who is Asian just like them, and meanwhile unbelievably trying to flatter white people.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>people: It was not well instructed, and we walked around the to wrong side and found we had to return completely to the other side for our tickets!</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: (+) Free palace tour in various languages so be sure to check the time if you are interested to join the tour
# (-) I remember a trip few years back where visitors could access the Secret Garden but now it requires a separate ticket and only accessible with a guided tour.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>amenities: (+) Free palace tour in various languages so be sure to check the time if you are interested to join the tour
# (-) I remember a trip few years back where visitors could access the Secret Garden but now it requires a separate ticket and only accessible with a guided tour.</s>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>management: (+) Free palace tour in various languages so be sure to check the time if you are interested to join the tour
# (-) I remember a trip few years back where visitors could access the Secret Garden but now it requires a separate ticket and only accessible with a guided tour.</s><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>nature: (+) Free palace tour in various languages so be sure to check the time if you are interested to join the tour
# (-) I remember a trip few years back where visitors could access the Secret Garden but now it requires a separate ticket and only accessible with a guided tour.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: However there was a cafe selling drinks, snacks and ice creams.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: However there was a cafe selling drinks, snacks and ice creams.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: The food here wasn't the best, so I'd recommend going between meals.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>management: Unfortunately largely destroyed and partially rebuilt but not very old in the first place.</s><pad><pad><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: There's a modern air conditioned cafe within the grounds, which is a godsend in the oppressive heat that Hue can conjure up during the summer months.</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>management: There's a modern air conditioned cafe within the grounds, which is a godsend in the oppressive heat that Hue can conjure up during the summer months.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: The Citadel was basically a large ruin spread over a large area partially restored and with limited information. It was really disappointing</s><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>amenities: The Citadel was basically a large ruin spread over a large area partially restored and with limited information. It was really disappointing</s><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>management: The Citadel was basically a large ruin spread over a large area partially restored and with limited information. It was really disappointing</s><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: A lot like the Forbidden City in Beijing but more crumbling and charming in its own way with shady trees and grasses.</s>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>all: The buildings the restoration team have touched are essentially vandalised; all sense of elegance and subtle has been painted over.</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>management: The buildings the restoration team have touched are essentially vandalised; all sense of elegance and subtle has been painted over.</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>management: Frankly we expected more about Hue, and the city is not really nice.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>amenities: Totally enjoyed walking around the Citadel with our private tour guide.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>nature: Visit the palace in a sunny day.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: Plastic bottles in the water, face masks and Coca Cola cans trash everywhere, many parts have annoying electric cars driving around tourists on tours and don't drive around you just really close and the constant beeping, families with strollers I felt really bad for.</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: If you have a drink at the outside cafe, check the price first - they seem to give a high price if you don't!</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>amenities: If you have a drink at the outside cafe, check the price first - they seem to give a high price if you don't!</s>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: Amusingly, most of the guards cannot grow beards, so they have fabric glued to their face.</s><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: Amusingly, most of the guards cannot grow beards, so they have fabric glued to their face.</s><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>management: Amusingly, most of the guards cannot grow beards, so they have fabric glued to their face.</s><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: Although the original buildings of Changdeokgung were destroyed by fire, the reconstruction are said to retain a high degree of authenticity.</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: Although the original buildings of Changdeokgung were destroyed by fire, the reconstruction are said to retain a high degree of authenticity.</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: Hue's Imperial City is vast, with lots of enticing, atmospheric corners and gardens that you could happily spend hours exploring.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: This place is vast, but very poorly maintained.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>cultural heritage: This place is vast, but very poorly maintained.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: There is a lot of walking but it's worth it.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>amenities: It was disappointeing that we could not get a map of the site and more of an idea of what we were viewing.</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>cultural heritage: I was very disappointed that they seemed to have just let everything rot, even though they charge an entrance fee of 150,000 dong for tourists.</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>people: I was very disappointed that they seemed to have just let everything rot, even though they charge an entrance fee of 150,000 dong for tourists.</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>nature: I was very disappointed that they seemed to have just let everything rot, even though they charge an entrance fee of 150,000 dong for tourists.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: Very busy when attended, but still an enjoyable experience, ornate decorations and gardens, once inside easy to forget you are in middle of city.</s><pad><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>management: Very busy when attended, but still an enjoyable experience, ornate decorations and gardens, once inside easy to forget you are in middle of city.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>nature: Very busy when attended, but still an enjoyable experience, ornate decorations and gardens, once inside easy to forget you are in middle of city.</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: The secret garden is ok but truly a very long walk and especially not for those too tired after visiting other areas in Seoul.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>management: There appears to be only one exit to one side, but well worth finding the old gardens not far from the exit (although it's not well signposted) as there is a cafe there serving drinks and food in lovely peaceful surroundings.</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: Not much to see here, but if you're into their culture you can pay a visit here too</s><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>cultural heritage: Not much to see here, but if you're into their culture you can pay a visit here too</s><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: Would of been better with a English speaking guide to tell you the history of the place but we saw it on our travels and just went in</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: This one was worth to enter for 3.000... Not supercool but different than others...</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: The site is interesting and it is nice to just sit and enjoy the view and relax away from the cyclos etc.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>people: The site is interesting and it is nice to just sit and enjoy the view and relax away from the cyclos etc.</s><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>management: Beautiful, convenient for wheel chairs and baby strollers.</s><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: I think anywhere requires admission should have a free tourist map!</s><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>amenities: Its nice but instead you can walk around the old city and see many of sites free.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: The Imperial City is a walled fortress and palace in the city of Huế, the former imperial capital of Vietnam.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: The Imperial City is a walled fortress and palace in the city of Huế, the former imperial capital of Vietnam.</s>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>amenities: The touring was finished at around 5:30pm and it was a very special experience lazing on a cyclo, seeing the city life when the streets were lit up and schoolgirls cycling home in their traditional long dresses.</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: Very well preserved palace with most beautiful garden.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: It was very beautiful and interesting, Cost 105000VND to get in and worth every VND.</s><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: Apart from the buildings there is not that much to see.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>cultural heritage: Apart from the buildings there is not that much to see.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>people: This place is overpriced, especially due to tourists being charged more than locals, if you tried to do that in my country you would be labeled a racists due to blatant discrimination.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: This place is overpriced, especially due to tourists being charged more than locals, if you tried to do that in my country you would be labeled a racists due to blatant discrimination.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: Great place to escape the hawkers and cyclos, 100000 entry for an adult which gives access to the royal museum as well.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>amenities: Great place to escape the hawkers and cyclos, 100000 entry for an adult which gives access to the royal museum as well.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: Great place to escape the hawkers and cyclos, 100000 entry for an adult which gives access to the royal museum as well.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>people: Great place to escape the hawkers and cyclos, 100000 entry for an adult which gives access to the royal museum as well.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>nature: Great place to escape the hawkers and cyclos, 100000 entry for an adult which gives access to the royal museum as well.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>amenities: We attended this attraction as part of our Intrepid tour and it is awesome!</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: In China, everything they restore just look brand new, as if it was built yesterday.</s><pad><pad><pad><pad><pad><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: In China, everything they restore just look brand new, as if it was built yesterday.</s><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: Besides the tens of thousands of civilian casualties, the conflict laid waste to most of the city and its historic structures.</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: there are lots of foods and snacks, and they are very CHEAP!</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: The well-preserved site, informative signage, and audio guides make it educational and visually impressive.</s><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: The buildings and grounds are really beautiful and work continues to restore the site further.</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>nature: The citadel is lit up (purple when I visited), very cool!</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: This palace is on the World Heritage List and deserves to be.</s><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>management: Totally unbearable and not for faint hearted we could do it all due to heat exhaustion.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: It's a large area that lasts back 200 years but given the amount of money they're making, the site is poorly maintained, hardly any valuable info visible and no real stunning buildings.</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>management: Only eat at the street food places near the bus station before the main entrance if you have no respect for your health or hygiene.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: Would really have loved to go in the Secret Garden but you need to be part of a guided tour to do this...why?</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>nature: Would really have loved to go in the Secret Garden but you need to be part of a guided tour to do this...why?</s>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>amenities: Cool to see the historic structures, but the audio guides need to be improved.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# ...
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: There is still so much damage to the beautiful buildings I was quite surprised we were allowed to visit some parts of the Citadel.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>all: Its wonderfully peaceful because there are no cyclos.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>people: Its wonderfully peaceful because there are no cyclos.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: Ticket is 150 000 dong per person, but the place is not well kept, with construction and degradation everywhere.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>amenities: Ticket is 150 000 dong per person, but the place is not well kept, with construction and degradation everywhere.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>cultural heritage: Ticket is 150 000 dong per person, but the place is not well kept, with construction and degradation everywhere.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: Ticket is 150 000 dong per person, but the place is not well kept, with construction and degradation everywhere.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>nature: Secret Garden) would be a mistake.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: They discontinued that some time back.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>people: Her attitude was lousy.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>management: Her attitude was lousy.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: Get only green taxi drivers with meters there are a lot of scams.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: I loved the old ruined part of the Citadel and I can appreciate what they are doing to restore it but I think it actually takes some of the charm away from it.</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>management: I loved the old ruined part of the Citadel and I can appreciate what they are doing to restore it but I think it actually takes some of the charm away from it.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>all: Once you get past the cyclo drivers offering tours, the Citadel is an impressive sight.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>amenities: Once you get past the cyclo drivers offering tours, the Citadel is an impressive sight.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>people: Once you get past the cyclo drivers offering tours, the Citadel is an impressive sight.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>amenities: We really enjoyed the cultural experience our guide was so informative and helpful.</s><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: Although this was the secondary palace of Gyeongbokung it’s landscaping along with with its design make it stand out above the rest.</s><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>nature: Although this was the secondary palace of Gyeongbokung it’s landscaping along with with its design make it stand out above the rest.</s>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: Tombs might be worse in terms of value.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>management: The grounds are immaculate, with beautiful flowers and landscaping.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>amenities: we departed at 2:30 multitude of interior, the car took us through the door compartment (under NetCoDo) has several cannons on either side of local roads, such as 9 brass deck gun big, heavy, elaborately carved, meticulous, every deck is longer than 5 feet, 9 lists on the pedestal of wood, the car took us to the nearest ticket and go find parking, not parking in them.</s>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>management: we departed at 2:30 multitude of interior, the car took us through the door compartment (under NetCoDo) has several cannons on either side of local roads, such as 9 brass deck gun big, heavy, elaborately carved, meticulous, every deck is longer than 5 feet, 9 lists on the pedestal of wood, the car took us to the nearest ticket and go find parking, not parking in them.</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>people: Many are more than happy to pose for you, if you ask nicely!</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>people: Having liked Hue as a city, and had a cyclo tour around the citadel (which we bargained hard for a good price and thoroughly enjoyed), my husband and I decided we would go to the Imperial City as recommended by our guide book.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: There is audio guide available and music performance of the imperial theatre.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>amenities: I read 'A bundle ticket for the Citadel and the tombs of Khai Dinh, Tu Duc and Minh Mang can be bought for 360,000VND (£12).</s>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: However, the saddest part I'd that I just checked the poor reviews for the citadel and another reviewer complained about the cruelty and abuse of the elephants almost a full year ago and obviously nothing has changed.</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>people: However, the saddest part I'd that I just checked the poor reviews for the citadel and another reviewer complained about the cruelty and abuse of the elephants almost a full year ago and obviously nothing has changed.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>cultural heritage: As such, this might be a preferred UNESCO attraction if you are limited in time during visits to Seoul.</s><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: It is a place that offers more things to see than Changgyeonggung Palace as it has buildings of the same level as Gyeongbokgung Palace, but the back garden (secret garden) is a place where part-time viewing is limited by advance reservation.</s><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>cultural heritage: It is a place that offers more things to see than Changgyeonggung Palace as it has buildings of the same level as Gyeongbokgung Palace, but the back garden (secret garden) is a place where part-time viewing is limited by advance reservation.</s>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>nature: It is a place that offers more things to see than Changgyeonggung Palace as it has buildings of the same level as Gyeongbokgung Palace, but the back garden (secret garden) is a place where part-time viewing is limited by advance reservation.</s><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>all: The history and cultural significance for central Vietnam cannot be understated but visually as a tourist destination and spectacle this vast overgrown walled city is nothing like the grandeur and quality of the Forbidden City in Beijing China.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>nature: The history and cultural significance for central Vietnam cannot be understated but visually as a tourist destination and spectacle this vast overgrown walled city is nothing like the grandeur and quality of the Forbidden City in Beijing China.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: The Secret garden trees were mostly bare in March. There is nothing of much interest if you compare this to the other grand gardens of the East or West. The guide(in English) for the palace was pleasant but the guide for the Secret Garden was a bit snotty and it is a long long walk so beware.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>amenities: The Secret garden trees were mostly bare in March. There is nothing of much interest if you compare this to the other grand gardens of the East or West. The guide(in English) for the palace was pleasant but the guide for the Secret Garden was a bit snotty and it is a long long walk so beware.</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>cultural heritage: The Secret garden trees were mostly bare in March. There is nothing of much interest if you compare this to the other grand gardens of the East or West. The guide(in English) for the palace was pleasant but the guide for the Secret Garden was a bit snotty and it is a long long walk so beware.</s>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>people: The Secret garden trees were mostly bare in March. There is nothing of much interest if you compare this to the other grand gardens of the East or West. The guide(in English) for the palace was pleasant but the guide for the Secret Garden was a bit snotty and it is a long long walk so beware.</s><pad>
# pred:  tensor(1, device='cuda:0')
# labels:  tensor(3, device='cuda:0')
#
# <s>management: The Secret garden trees were mostly bare in March. There is nothing of much interest if you compare this to the other grand gardens of the East or West. The guide(in English) for the palace was pleasant but the guide for the Secret Garden was a bit snotty and it is a long long walk so beware.</s><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# <s>nature: The Secret garden trees were mostly bare in March. There is nothing of much interest if you compare this to the other grand gardens of the East or West. The guide(in English) for the palace was pleasant but the guide for the Secret Garden was a bit snotty and it is a long long walk so beware.</s><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: More expensive than any single royal tomb, but less impressive if more massive.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>amenities: More expensive than any single royal tomb, but less impressive if more massive.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>cultural heritage: More expensive than any single royal tomb, but less impressive if more massive.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>amenities: It amazes me that anyone would complain about this palace (I've seen some reviews) since the price is very reasonable and you can spend a lot of time here getting many different kinds of shots.</s>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(1, device='cuda:0')
#
# <s>all: The food in the cafes is over priced with small portions so bring your own snacks.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# pred:  tensor(3, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>nature: It rained heavily during our visit and poor drainage meant the paths and open areas were flooded, making it difficult to get around the site.</s><pad>
# pred:  tensor(0, device='cuda:0')
# labels:  tensor(2, device='cuda:0')
#
# <s>all: Gosh!!!</s><pad><pad><pad><pad>
# pred:  tensor(2, device='cuda:0')
# labels:  tensor(0, device='cuda:0')
#
# all-1 recall= 0.896 precision= 0.9038 f1= 0.8999
# amn-0 recall= 0.9635 precision= 0.9111 f1= 0.9366
# ch-1 recall= 0.7273 precision= 0.8627 f1= 0.7892
# ppl-0 recall= 0.9716 precision= 0.9775 f1= 0.9746
# mgt-0 recall= 0.9348 precision= 0.9739 f1= 0.9539
# nat-0 recall= 0.959 precision= 0.969 f1= 0.964
# all-2 recall= 0.9132 precision= 0.8811 f1= 0.8969
# ch-0 recall= 0.9348 precision= 0.9291 f1= 0.932
# mgt-2 recall= 0.8228 precision= 0.7303 f1= 0.7738
# ch-2 recall= 0.949 precision= 0.7815 f1= 0.8571
# nat-1 recall= 0.8537 precision= 0.7865 f1= 0.8187
# amn-1 recall= 0.7395 precision= 0.8381 f1= 0.7857
# all-3 recall= 0.6381 precision= 0.7444 f1= 0.6872
# amn-2 recall= 0.6338 precision= 0.7895 f1= 0.7031
# mgt-1 recall= 0.7561 precision= 0.62 f1= 0.6813
# amn-3 recall= 0.3077 precision= 0.3636 f1= 0.3333
# all-0 recall= 0.7407 precision= 0.625 f1= 0.678
# nat-2 recall= 0.7547 precision= 0.8511 f1= 0.8
# ch-3 recall= 0.5 precision= 0.7778 f1= 0.6087
# mgt-3 recall= 0.5 precision= 0.2727 f1= 0.3529
# ppl-2 recall= 0.5833 precision= 0.6667 f1= 0.6222
# ppl-1 recall= 0.8148 precision= 0.7857 f1= 0.8
# ppl-3 recall= 0.3333 precision= 0.1111 f1= 0.1667
# nat-3 recall= 1.0 precision= 0.375 f1= 0.5455
# 3924 4344
# Accuracy: 0.90331
# Loss: 0.3183523385720464
# Marco-recall: 0.75949
# Marco-precision: 0.7303
# Marco-f1: 0.73172
